// %%
%python
2+2

// %%
dbutils.fs.mkdirs("/mnt/dados")

// %%
dbutils.fs.ls("/mnt")

// %%
val configs = Map(
  "fs.azure.account.auth.type" -> "OAuth",
  "fs.azure.account.oauth.provider.type" -> "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
  "fs.azure.account.oauth2.client.id" -> "**id-app**",
  "fs.azure.account.oauth2.client.secret" -> "**value-client-secret**",
  "fs.azure.account.oauth2.client.endpoint" -> "https://login.microsoftonline.com/**id-diretorio**/oauth2/token")
// Optionally, you can add <directory-name> to the source URI of your mount point.
dbutils.fs.mount(
  source = "abfss://imoveis@allyssondatalake.dfs.core.windows.net/",
  mountPoint = "/mnt/dados",
  extraConfigs = configs)

// %%
dbutils.fs.ls("/mnt/dados")
